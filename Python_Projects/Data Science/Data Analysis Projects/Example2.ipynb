# %%
"""
The first thing that we have to do, is we have to import the necessary dependencies, 
that we will be using in the upcoming part of the program. Here in this project, we shall be using numpy, pandas, matplotlib, sklearn.
"""
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
gold_data = pd.read_csv('gld_price_data.csv')
print(gold_data)
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
gold_data.head(20)
# Out:
#          Date          SPX        GLD        USO        SLV   EUR/USD
# 0    1/2/2008  1447.160034  84.860001  78.470001  15.180000  1.471692
# 1    1/3/2008  1447.160034  85.570000  78.370003  15.285000  1.474491
# 2    1/4/2008  1411.630005  85.129997  77.309998  15.167000  1.475492
# 3    1/7/2008  1416.180054  84.769997  75.500000  15.053000  1.468299
# 4    1/8/2008  1390.189941  86.779999  76.059998  15.590000  1.557099
# 5    1/9/2008  1409.130005  86.550003  75.250000  15.520000  1.466405
# 6   1/10/2008  1420.329956  88.250000  74.019997  16.061001  1.480100
# 7   1/11/2008  1401.020020  88.580002  73.089996  16.077000  1.479006
# 8   1/14/2008  1416.250000  89.540001  74.250000  16.280001  1.486900
# 9   1/15/2008  1380.949951  87.989998  72.779999  15.834000  1.480210
# 10  1/16/2008  1373.199951  86.699997  71.849998  15.654000  1.466405
# 11  1/17/2008  1333.250000  86.500000  71.029999  15.717000  1.464000
# ...

# %%
"""
Now, let’s check how many cells are left empty in the table, to get a better insight  : 
"""
gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
x=gold_data['Date']
y=gold_data['EUR/USD']

plt.plot(x,y,'r.')
plt.show()
