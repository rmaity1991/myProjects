# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
liver_data_master=pd.read_csv("Indian Liver Patient Dataset.csv")

print(liver_data_master)
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [583 rows x 11 columns]

# %%
df=liver_data_master.copy()
print(df)
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [583 rows x 11 columns]

# %%
df.shape
# Out:
# (583, 11)

# %%
df.size
# Out:
# 6413

# %%
df.keys
# Out:
# <bound method NDFrame.keys of      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot', 'TP', 'ALB',
#        'AG', 'LiverPatient'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           583 non-null    int64
#  1   Gender        583 non-null    object
#  2   TB            583 non-null    float64
#  3   DB            583 non-null    float64
#  4   Alkphos       583 non-null    int64
#  5   Sgpt          583 non-null    int64
#  6   Sgot          583 non-null    int64
#  7   TP            583 non-null    float64
#  8   ALB           583 non-null    float64
#  9   AG            579 non-null    float64
#  10  LiverPatient  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  LiverPatient
# count   583.000000  583.000000  583.000000  579.000000    583.000000
# mean    109.910806    6.483190    3.141852    0.947064      1.286449
# std     288.918529    1.085451    0.795519    0.319592      0.452490
# min      10.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
df.head(5)
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1

# %%
df.tail(5)
# Out:
#      Age Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 578   60   Male  0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40   Male  0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52   Male  0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31   Male  1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38   Male  1.0  0.3      216    21    24  7.3  4.4  1.50             2

# %%
df_male=df[df['Gender']=='Male'] # Take the Male Data in one data frame
print(df_male)

plt.scatter(df_male['Age'],df_male['TB'])
plt.show()
# Out:
#      Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 1     62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5     46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1
# ..   ...    ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60   Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40   Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52   Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31   Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38   Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [441 rows x 11 columns]

# %%
df_female=df[df['Gender']=='Female'] # Take the female Data in one data frame
print(df_female)

plt.scatter(df_female['Age'],df_female['TB'])
plt.show()
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  \
# 0     65  Female   0.7   0.1      187    16    18  6.8  3.3  0.90
# 6     26  Female   0.9   0.2      154    16    12  7.0  3.5  1.00
# 7     29  Female   0.9   0.3      202    14    11  6.7  3.6  1.10
# 13    74  Female   1.1   0.4      214    22    30  8.1  4.1  1.00
# 18    40  Female   0.9   0.3      293   232   245  6.8  3.1  0.80
# ..   ...     ...   ...   ...      ...   ...   ...  ...  ...   ...
# 547   50  Female  27.7  10.8      380    39   348  7.1  2.3  0.40
# 549   40  Female   2.1   1.0      768    74   141  7.8  4.9  1.60
# 564   38  Female   0.6   0.1      165    22    34  5.9  2.9  0.90
# 566   50  Female   1.0   0.3      191    22    31  7.8  4.0  1.00
# 568   20  Female  16.7   8.4      200    91   101  6.9  3.5  1.02
#
#      LiverPatient
# 0               1
# 6               1
# 7               1
# 13              1
# 18              1
# ..            ...
# 547             1
# ...

# %%
df_male
# Out:
#      Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 1     62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5     46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1
# ..   ...    ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60   Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40   Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52   Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31   Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38   Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [441 rows x 11 columns]

# %%
df_male[['Age','Alkphos']].head(10)
# Out:
#     Age  Alkphos
# 1    62      699
# 2    62      490
# 3    58      182
# 4    72      195
# 5    46      208
# 8    17      202
# 9    55      290
# 10   57      210
# 11   72      260
# 12   64      310

# %%
df_male[['Age','Alkphos']].describe()
# Out:
#               Age      Alkphos
# count  441.000000   441.000000
# mean    45.265306   286.789116
# std     16.266108   221.591533
# min      4.000000    75.000000
# 25%     33.000000   179.000000
# 50%     45.000000   215.000000
# 75%     60.000000   298.000000
# max     90.000000  2110.000000

# %%
df_male
# Out:
#      Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 1     62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5     46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1
# ..   ...    ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60   Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40   Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52   Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31   Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38   Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [441 rows x 11 columns]

# %%
df_male['Sgpt-Sgpt.Mean']=df_male['Sgpt']-df_male['Sgpt'].mean()
# Out:
# C:\Users\11037833\AppData\Local\Temp\ipykernel_36516\3922250711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_male['Sgpt-Sgpt.Mean']=df_male['Sgpt']-df_male['Sgpt'].mean()

# %%
df_male=df_male.drop(['Sgpt-Sgpt.Mean'],axis=1)

# %%
df_male.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  441.000000  441.000000  441.000000   441.000000   441.000000
# mean    45.265306    3.613152    1.646032   286.789116    89.238095
# std     16.266108    6.558631    2.912807   221.591533   202.438273
# min      4.000000    0.400000    0.100000    75.000000    10.000000
# 25%     33.000000    0.800000    0.200000   179.000000    25.000000
# 50%     45.000000    1.200000    0.400000   215.000000    38.000000
# 75%     60.000000    2.900000    1.500000   298.000000    65.000000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  LiverPatient
# count   441.000000  441.000000  441.000000  439.000000    441.000000
# mean    123.070295    6.428345    3.099546    0.946446      1.265306
# std     323.216916    1.064762    0.780967    0.329313      0.441997
# min      11.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
df_male_condition1=df_male[df_male['Alkphos']>(df_male['Alkphos'].mean())]
df_male_condition1
# Out:
#      Age Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 1     62   Male  10.9   5.5      699    64   100  7.5  3.2  0.74             1
# 2     62   Male   7.3   4.1      490    60    68  7.0  3.3  0.89             1
# 9     55   Male   0.7   0.2      290    53    58  6.8  3.4  1.00             1
# 12    64   Male   0.9   0.3      310    61    58  7.0  3.4  0.90             2
# 16    38   Male   1.8   0.8      342   168   441  7.6  4.4  1.30             1
# ..   ...    ...   ...   ...      ...   ...   ...  ...  ...   ...           ...
# 573   32   Male   3.7   1.6      612    50    88  6.2  1.9  0.40             1
# 574   32   Male  12.1   6.0      515    48    92  6.6  2.4  0.50             1
# 575   32   Male  25.0  13.7      560    41    88  7.9  2.5  2.50             1
# 576   32   Male  15.0   8.2      289    58    80  5.3  2.2  0.70             1
# 578   60   Male   0.5   0.1      500    20    34  5.9  1.6  0.37             2
#
# [125 rows x 11 columns]
