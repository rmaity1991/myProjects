# %% [markdown]
# Here we will using the Indian Liver Dataset as our reference. So we will display all the most commonly used methods of
# analysis from pandas library

# %%
import pandas as pd

# %%
liver_data=pd.read_csv('Indian Liver Patient Dataset.csv')
print(liver_data)
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [583 rows x 11 columns]

# %%
liver_data
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [583 rows x 11 columns]

# %%
liver_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           583 non-null    int64
#  1   Gender        583 non-null    object
#  2   TB            583 non-null    float64
#  3   DB            583 non-null    float64
#  4   Alkphos       583 non-null    int64
#  5   Sgpt          583 non-null    int64
#  6   Sgot          583 non-null    int64
#  7   TP            583 non-null    float64
#  8   ALB           583 non-null    float64
#  9   AG            579 non-null    float64
#  10  LiverPatient  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
liver_data.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  LiverPatient
# count   583.000000  583.000000  583.000000  579.000000    583.000000
# mean    109.910806    6.483190    3.141852    0.947064      1.286449
# std     288.918529    1.085451    0.795519    0.319592      0.452490
# min      10.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
liver_data['Age'].describe()
# Out:
# count    583.000000
# mean      44.746141
# std       16.189833
# min        4.000000
# 25%       33.000000
# 50%       45.000000
# 75%       58.000000
# max       90.000000
# Name: Age, dtype: float64

# %%
liver_data.head(10)
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5   46    Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1
# 6   26  Female   0.9  0.2      154    16    12  7.0  3.5  1.00             1
# 7   29  Female   0.9  0.3      202    14    11  6.7  3.6  1.10             1
# 8   17    Male   0.9  0.3      202    22    19  7.4  4.1  1.20             2
# 9   55    Male   0.7  0.2      290    53    58  6.8  3.4  1.00             1

# %%
liver_data.sample()
# Out:
#      Age Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 416   70   Male  0.6  0.1      862    76   180  6.3  2.7  0.75             1

# %%
liver_data.sample(10)
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  \
# 92    60    Male   8.6   4.0      298   412   850  7.4  3.0  0.60
# 478   33    Male   7.1   3.7      196   622   497  6.9  3.6  1.09
# 239   40    Male   0.9   0.3      196    69    48  6.8  3.1  0.80
# 401   50    Male   7.3   3.7       92    44   236  6.8  1.6  0.30
# 246   55    Male   1.8   9.0      272    22    79  6.1  2.7  0.70
# 1     62    Male  10.9   5.5      699    64   100  7.5  3.2  0.74
# 447   45  Female  23.3  12.8     1550   425   511  7.7  3.5  0.80
# 25    34    Male   4.1   2.0      289   875   731  5.0  2.7  1.10
# 532   62    Male   0.7   0.2      162    12    17  8.2  3.2  0.60
# 397   78    Male   1.0   0.3      152    28    70  6.3  3.1  0.90
#
#      LiverPatient
# 92              1
# 478             1
# 239             1
# 401             1
# 246             1
# 1               1
# 447             1
# 25              1
# 532             2
# 397             1

# %%
liver_data_male=liver_data[liver_data['Gender']=='Male']
liver_data_female=liver_data[liver_data['Gender']=='Female']

# %%
liver_data_female
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  \
# 0     65  Female   0.7   0.1      187    16    18  6.8  3.3  0.90
# 6     26  Female   0.9   0.2      154    16    12  7.0  3.5  1.00
# 7     29  Female   0.9   0.3      202    14    11  6.7  3.6  1.10
# 13    74  Female   1.1   0.4      214    22    30  8.1  4.1  1.00
# 18    40  Female   0.9   0.3      293   232   245  6.8  3.1  0.80
# ..   ...     ...   ...   ...      ...   ...   ...  ...  ...   ...
# 547   50  Female  27.7  10.8      380    39   348  7.1  2.3  0.40
# 549   40  Female   2.1   1.0      768    74   141  7.8  4.9  1.60
# 564   38  Female   0.6   0.1      165    22    34  5.9  2.9  0.90
# 566   50  Female   1.0   0.3      191    22    31  7.8  4.0  1.00
# 568   20  Female  16.7   8.4      200    91   101  6.9  3.5  1.02
#
#      LiverPatient
# 0               1
# 6               1
# 7               1
# 13              1
# 18              1
# ..            ...
# 547             1
# ...

# %%
liver_data_male[['Gender','Age','TB']].head(10)
# Out:
#    Gender  Age    TB
# 1    Male   62  10.9
# 2    Male   62   7.3
# 3    Male   58   1.0
# 4    Male   72   3.9
# 5    Male   46   1.8
# 8    Male   17   0.9
# 9    Male   55   0.7
# 10   Male   57   0.6
# 11   Male   72   2.7
# 12   Male   64   0.9

# %%
liver_data_male[['Gender','Age','TB']].tail(10)
# Out:
#     Gender  Age    TB
# 573   Male   32   3.7
# 574   Male   32  12.1
# 575   Male   32  25.0
# 576   Male   32  15.0
# 577   Male   32  12.7
# 578   Male   60   0.5
# 579   Male   40   0.6
# 580   Male   52   0.8
# 581   Male   31   1.3
# 582   Male   38   1.0

# %%
liver_data_male['Age'].values
# Out:
# array([62, 62, 58, 72, 46, 17, 55, 57, 72, 64, 61, 25, 38, 33, 51, 51, 62,
#        40, 63, 34, 34, 34, 20, 57, 52, 57, 30, 48, 47, 45, 62, 42, 50, 35,
#        21, 40, 55, 38, 38, 42, 42, 33, 51, 64, 58, 58, 57, 57, 57, 54, 37,
#        66, 60, 52, 68, 31, 70, 29, 49, 33, 32, 14, 13, 58, 18, 60, 60, 60,
#        60, 60, 60, 75, 39, 39, 18, 18, 27, 27, 17, 63, 36, 36, 36, 36, 36,
#        48, 27, 74, 50, 50, 48, 32, 32, 32, 32, 32, 58, 28, 60, 48, 64, 45,
#        45, 53, 18, 66, 18, 18, 15, 60, 30, 30, 65, 65, 50, 60, 56, 50, 52,
#        34, 34, 32, 72, 72, 50, 60, 60, 60, 39, 39, 48, 55, 60, 60, 72, 55,
#        31, 31, 31, 55, 75, 75, 75, 75, 75, 65, 40, 64, 38, 60, 60, 60, 60,
#        60, 60, 49, 49, 60, 60, 41, 49, 49, 21, 21, 45, 40, 40, 28, 42, 22,
#        38, 66, 55, 49,  6, 37, 37, 47, 47, 50, 70, 26, 26, 46, 61, 61, 50,
#        33, 60, 22, 40, 48, 51, 54, 54, 55, 55, 40, 33, 33, 33, 65, 38, 50,
# ...

# %%
type(liver_data_male['Age'].values)
# Out:
# numpy.ndarray

# %%
import numpy as np

np.mean(liver_data_male['Age'].values)
# Out:
# 45.265306122448976

# %%
liver_data_male.columns
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot', 'TP', 'ALB',
#        'AG', 'LiverPatient'],
#       dtype='object')

# %%
np.mean(liver_data_male['Sgot'].values)
# Out:
# 123.0702947845805

# %%
type(liver_data_male['Sgot'].values)
# Out:
# numpy.ndarray

# %%
liver_data_male.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  441.000000  441.000000  441.000000   441.000000   441.000000
# mean    45.265306    3.613152    1.646032   286.789116    89.238095
# std     16.266108    6.558631    2.912807   221.591533   202.438273
# min      4.000000    0.400000    0.100000    75.000000    10.000000
# 25%     33.000000    0.800000    0.200000   179.000000    25.000000
# 50%     45.000000    1.200000    0.400000   215.000000    38.000000
# 75%     60.000000    2.900000    1.500000   298.000000    65.000000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  LiverPatient
# count   441.000000  441.000000  441.000000  439.000000    441.000000
# mean    123.070295    6.428345    3.099546    0.946446      1.265306
# std     323.216916    1.064762    0.780967    0.329313      0.441997
# min      11.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
liver_data_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 0 to 568
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           142 non-null    int64
#  1   Gender        142 non-null    object
#  2   TB            142 non-null    float64
#  3   DB            142 non-null    float64
#  4   Alkphos       142 non-null    int64
#  5   Sgpt          142 non-null    int64
#  6   Sgot          142 non-null    int64
#  7   TP            142 non-null    float64
#  8   ALB           142 non-null    float64
#  9   AG            140 non-null    float64
#  10  LiverPatient  142 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 13.3+ KB

# %%
liver_data_female.columns
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'Alkphos', 'Sgpt', 'Sgot', 'TP', 'ALB',
#        'AG', 'LiverPatient'],
#       dtype='object')

# %%
liver_data_female['Age'].mean()
# Out:
# 43.13380281690141

# %%
liver_data_female['Age'].median()
# Out:
# 45.0

# %%
liver_data_female['Age'].max()
# Out:
# 85

# %%
liver_data_female['Age'].min()
# Out:
# 7

# %%
liver_data_female['Age'].nsmallest().head(10)
# Out:
# 199     7
# 213     8
# 537    10
# 334    13
# 335    13
# Name: Age, dtype: int64

# %%
liver_data_female['Age'].nlargest().head()
# Out:
# 44    85
# 29    84
# 71    75
# 72    75
# 13    74
# Name: Age, dtype: int64

# %%
liver_data_female.sort_values(by='Age',ascending=False)
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB   AG  LiverPatient
# 44    85  Female   1.0   0.3      208    17    15  7.0  3.6  1.0             2
# 29    84  Female   0.7   0.2      188    13    21  6.0  3.2  1.1             2
# 71    75  Female   0.8   0.2      188    20    29  4.4  1.8  0.6             1
# 72    75  Female   0.8   0.2      205    27    24  4.4  2.0  0.8             1
# 13    74  Female   1.1   0.4      214    22    30  8.1  4.1  1.0             1
# ..   ...     ...   ...   ...      ...   ...   ...  ...  ...  ...           ...
# 334   13  Female   0.7   0.2      350    17    24  7.4  4.0  1.1             1
# 335   13  Female   0.7   0.1      182    24    19  8.9  4.9  1.2             1
# 537   10  Female   0.8   0.1      395    25    75  7.6  3.6  0.9             1
# 213    8  Female   0.9   0.2      401    25    58  7.5  3.4  0.8             1
# 199    7  Female  27.2  11.8     1420   790  1050  6.1  2.0  0.4             1
#
# [142 rows x 11 columns]

# %%
liver_data_female.sort_values(by='Alkphos',ascending=False)
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  \
# 128   58  Female   1.7   0.8     1896    61    83  8.0  3.9  0.95
# 77    68  Female   0.6   0.1     1620    95   127  4.6  2.1  0.80
# 447   45  Female  23.3  12.8     1550   425   511  7.7  3.5  0.80
# 199    7  Female  27.2  11.8     1420   790  1050  6.1  2.0  0.40
# 420   55  Female  10.9   5.1     1350    48    57  6.4  2.3  0.50
# ..   ...     ...   ...   ...      ...   ...   ...  ...  ...   ...
# 530   22  Female   1.1   0.3      138    14    21  7.0  3.8  1.10
# 466   28  Female   0.6   0.1      137    22    16  4.9  1.9  0.60
# 369   58  Female   0.8   0.2      130    24    25  7.0  4.0  1.30
# 467   28  Female   1.0   0.3       90    18   108  6.8  3.1  0.80
# 320   30  Female   0.7   0.2       63    31    27  5.8  3.4  1.40
#
#      LiverPatient
# 128             1
# 77              1
# 447             1
# 199             1
# 420             1
# ..            ...
# 530             2
# ...

# %%
liver_data_female_above_50=liver_data_female[liver_data_female['Age']>=50]

# %%
liver_data_female_above_50
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  \
# 0     65  Female   0.7   0.1      187    16    18  6.8  3.3  0.90
# 13    74  Female   1.1   0.4      214    22    30  8.1  4.1  1.00
# 29    84  Female   0.7   0.2      188    13    21  6.0  3.2  1.10
# 44    85  Female   1.0   0.3      208    17    15  7.0  3.6  1.00
# 71    75  Female   0.8   0.2      188    20    29  4.4  1.8  0.60
# 72    75  Female   0.8   0.2      205    27    24  4.4  2.0  0.80
# 77    68  Female   0.6   0.1     1620    95   127  4.6  2.1  0.80
# 79    58  Female   2.8   1.3      670    48    79  4.7  1.6  0.50
# 80    58  Female   2.4   1.1      915    60   142  4.7  1.8  0.60
# 103   55  Female   0.8   0.2      225    14    23  6.1  3.3  1.20
# 123   64  Female   0.8   0.2      178    17    18  6.3  3.1  0.90
# 128   58  Female   1.7   0.8     1896    61    83  8.0  3.9  0.95
# 131   70  Female   0.7   0.2      237    18    28  5.8  2.5  0.75
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(liver_data_female_above_50['TB'],liver_data_female_above_50['Age'])
plt.show()

# %%
plt.scatter(liver_data_female_above_50['Alkphos'],liver_data_female_above_50['Age'])
plt.show()

# %%
plt.scatter(liver_data_female_above_50['TP'],liver_data_female_above_50['Age'])
plt.show()

# %%
liver_data_male
# Out:
#      Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 1     62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5     46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1
# ..   ...    ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60   Male   0.5  0.1      500    20    34  5.9  1.6  0.37             2
# 579   40   Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52   Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31   Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38   Male   1.0  0.3      216    21    24  7.3  4.4  1.50             2
#
# [441 rows x 11 columns]

# %%
liver_data_female
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  \
# 0     65  Female   0.7   0.1      187    16    18  6.8  3.3  0.90
# 6     26  Female   0.9   0.2      154    16    12  7.0  3.5  1.00
# 7     29  Female   0.9   0.3      202    14    11  6.7  3.6  1.10
# 13    74  Female   1.1   0.4      214    22    30  8.1  4.1  1.00
# 18    40  Female   0.9   0.3      293   232   245  6.8  3.1  0.80
# ..   ...     ...   ...   ...      ...   ...   ...  ...  ...   ...
# 547   50  Female  27.7  10.8      380    39   348  7.1  2.3  0.40
# 549   40  Female   2.1   1.0      768    74   141  7.8  4.9  1.60
# 564   38  Female   0.6   0.1      165    22    34  5.9  2.9  0.90
# 566   50  Female   1.0   0.3      191    22    31  7.8  4.0  1.00
# 568   20  Female  16.7   8.4      200    91   101  6.9  3.5  1.02
#
#      LiverPatient
# 0               1
# 6               1
# 7               1
# 13              1
# 18              1
# ..            ...
# 547             1
# ...

# %%
plt.scatter(liver_data_female['Age'],liver_data_female['TP'])
plt.show()

# %%
plt.scatter(liver_data_male['Age'],liver_data_male['TP'])
plt.show()
